# %% [markdown]
# <a href="https://colab.research.google.com/github/AsadAI-Official/dice-roller/blob/main/Dice%20Roller%20%E2%80%93%20Python%20Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

print("🎲 Dice Roller")
print("Press Enter to roll the dice")
print("Type 'q' to quit\n")

while True:
    user = input("Roll? ")

    if user.lower() == "q":
        print("Goodbye!")
        break

    dice = random.randint(1, 6)
    print("You rolled:", dice)
# Out:
# 🎲 Dice Roller
# Press Enter to roll the dice
# Type 'q' to quit
#
# Roll?
# You rolled: 4
# Roll?
# You rolled: 1
# Roll?
# You rolled: 6
# Roll?
# You rolled: 6
# Roll?
# You rolled: 1
# Roll?
# You rolled: 6
# Roll?
# You rolled: 4
# Roll?
# You rolled: 4
# Roll?
# You rolled: 5
# Roll?
# You rolled: 5
# Roll?
# You rolled: 1
# Roll?
# You rolled: 3
# Roll?
# You rolled: 3
# Roll?
# You rolled: 5
